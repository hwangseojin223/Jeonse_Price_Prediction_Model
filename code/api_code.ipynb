# %%
# 터미널에서 다운받기
# pip install PublicDataReader --upgrade

# %% [markdown]
# ![image.png](attachment:image.png)`

# %%
# open api 활용하기  (개인 키 쓰기!)
service_key = "vfY4VBbDDWnxBlsur1HG1qugKmYTCVY1e5g%2F8DvvKUsrqH2D%2FtDAqtT3VHoNq8zIXWmS5iFYfgGBBGBe5W%2FoOQ%3D%3D"
from PublicDataReader import TransactionPrice
api = TransactionPrice(service_key)

# %%
# 특정 년월 자료만 조회하기
df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11200",
    start_year_month = "201501",
    end_year_month = "202212"
    )
df.to_csv('seongdong.csv', encoding='euc-kr')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 특정 년월 자료만 조회하기
# ----> 2 df = api.get_data(
#       3     property_type="연립다세대",
#       4     trade_type="전월세",
#       5     sigungu_code="11200",
#       6     start_year_month = "201501",
#       7     end_year_month = "202212"
#       8     )
#       9 df.to_csv('seongdong.csv', encoding='euc-kr')
#
# File C:\Anaconda3\Lib\site-packages\PublicDataReader\PublicDataPortal\molit.py:173, in TransactionPrice.get_data(self, property_type, trade_type, sigungu_code, year_month, start_year_month, end_year_month, verbose, **kwargs)
#     171     print(year_month)
#     172 params['DEAL_YMD'] = year_month
# --> 173 res = requests.get(url, params=params, verify=False)
#     174 res_json = xmltodict.parse(res.text)
#     175 if res_json['response']['header']['resultCode'] != '00':
#
# ...

# %%
# 서울시 법정동 코드
# 강남구 Gangnam-gu 11680 
# 강동구 Gangdong-gu 11740
# 강북구 Gangbuk-gu 11305 
# 강서구 Gangseo-gu 11500
# 관악구 Gwanak-gu 11620
# 광진구 Gwangjin-gu 11215 
# 구로구 Guro-gu 11530 
# 금천구 Geumcheon-gu 11545 
# 노원구 Nowon-gu 11350 
# 도봉구 Dobong-gu 11320 
# 동대문구 Dongdaemun-gu 11230
# 동작구 Dongjak-gu 11590
# 마포구 Mapo-gu 11440 
# 서대문구 Seodaemun-gu 11410 
# 서초구 Seocho-gu 11650 
# 성동구 Seongdong-gu 11200
# 성북구 Seongbuk-gu 11290
# 송파구 Songpa-gu 11710
# 양천구 Yangcheon-gu 11470
# 영등포구 Yeongdeungpo-gu 11560
# 용산구 Yongsan-gu 11170
# 은평구 Eunpyeong-gu 11380 
# 종로구 Jongno-gu 11110
# 중구 Jung-gu 11140
# 중랑구 Jungnang-gu 11260

# %%
# 성동구
gangnam_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11200",
    start_year_month = "201501",
    end_year_month = "202212"
    )

display(gangnam_df.head())
# Out:
#     지역코드    법정동       지번   연립다세대  건축년도  층   전용면적     년  월   일   보증금액  월세금액  \
# 0  11200  하왕십리동  890-401  광진연립B동  1986  3  39.70  2015  1   9  15000     0
# 1  11200  하왕십리동  890-114      수빌  2012  4  13.97  2015  1  10   3000    30
# 2  11200    홍익동      125    동아맨션  1977  3  85.36  2015  1  19  17000     0
# 3  11200    홍익동      367   리더스파크  2014  2  27.45  2015  1  21  19000     0
# 4  11200    도선동      188     도선빌  2012  5  17.56  2015  1  10   6000    30
#
#    계약구분  계약기간 갱신요구권사용  종전계약보증금  종전계약월세
# 0  None  None    None     <NA>    <NA>
# 1  None  None    None     <NA>    <NA>
# 2  None  None    None     <NA>    <NA>
# 3  None  None    None     <NA>    <NA>
# 4  None  None    None     <NA>    <NA>

# %%
# 강동구
gangdong_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11740",
    start_year_month = "201501",
    end_year_month = "202212"
    )
display(gangdong_df.head())
# Out:
#     지역코드  법정동       지번     연립다세대  건축년도  층   전용면적     년  월   일   보증금액  월세금액  \
# 0  11740  명일동    328-8    재경아트빌라  1992  2  83.70  2015  1   3  27000     0
# 1  11740  명일동  312-182   진양그린빌리지  1996  3  84.89  2015  1  10  18000    25
# 2  11740  명일동   322-11     반석빌리지  2012  5  36.61  2015  1  10  15500     0
# 3  11740  명일동   336-18  (336-18)  2012  2  17.76  2015  1  12    500    43
# 4  11740  명일동    332-3      아름누리  2014  2  53.16  2015  1  12  25000     0
#
#    계약구분  계약기간 갱신요구권사용  종전계약보증금  종전계약월세
# 0  None  None    None     <NA>    <NA>
# 1  None  None    None     <NA>    <NA>
# 2  None  None    None     <NA>    <NA>
# 3  None  None    None     <NA>    <NA>
# 4  None  None    None     <NA>    <NA>
#         지역코드  법정동      지번      연립다세대  건축년도  층    전용면적     년   월   일   보증금액  \
# 48073  11740  천호동   560-2        더하임  2022  8  13.470  2022  12  30   1000
# 48074  11740  천호동  333-37     333-37  2019  4  25.495  2022  12  30  23000
# ...

# %%
# 강북구
gangbuk_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11305",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(gangbuk_df.head())
print(gangbuk_df.tail())
# Out:
#     지역코드  법정동        지번       연립다세대  건축년도  층   전용면적     년  월  일   보증금액  월세금액  \
# 0  11305  미아동     133-1     와이센선라이즈  2002  3  75.52  2015  1  2  18000     0
# 1  11305  미아동  791-1529  (791-1529)  1999  3  40.38  2015  1  2   7500     0
# 2  11305  미아동   1365-16       현대빌라트  2001  2  52.07  2015  1  3   4000    45
# 3  11305  미아동    306-33    (306-33)  2014  4  25.16  2015  1  5  13000     0
# 4  11305  미아동  791-2798  (791-2798)  2008  4  28.25  2015  1  5   6000     0
#
#    계약구분  계약기간 갱신요구권사용  종전계약보증금  종전계약월세
# 0  None  None    None     <NA>    <NA>
# 1  None  None    None     <NA>    <NA>
# 2  None  None    None     <NA>    <NA>
# 3  None  None    None     <NA>    <NA>
# 4  None  None    None     <NA>    <NA>
#         지역코드  법정동      지번    연립다세대  건축년도  층   전용면적     년   월   일   보증금액  월세금액  \
# 17612  11305  우이동    20-2     우림빌라  1994  3  31.36  2022  12  21   2800     0
# 17613  11305  우이동   56-49    GY펠리체  2018  5  27.20  2022  12  22  18000     0
# ...

# %%
# 강서구
gangseo_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11500",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(gangseo_df.head())
# print(gangseo_df.tail())
# Out:
#     지역코드  법정동      지번     연립다세대  건축년도  층   전용면적     년  월   일   보증금액  월세금액  \
# 0  11500  염창동  277-19  (277-19)  2005  2  85.54  2015  1   2   3000    90
# 1  11500  염창동  282-15     그린하우스  2012  7  12.20  2015  1   3   3000    30
# 2  11500  염창동  278-13      서울빌라  1991  1  84.52  2015  1  10  12000    40
# 3  11500  염창동  241-16    명주빌하모니  2010  3  45.08  2015  1  10  16000     0
# 4  11500  염창동  282-15     그린하우스  2012  7  12.20  2015  1  10   2000    35
#
#    계약구분  계약기간 갱신요구권사용  종전계약보증금  종전계약월세
# 0  None  None    None     <NA>    <NA>
# 1  None  None    None     <NA>    <NA>
# 2  None  None    None     <NA>    <NA>
# 3  None  None    None     <NA>    <NA>
# 4  None  None    None     <NA>    <NA>

# %%
# 관악구
gwanak_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11620",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(gwanak_df.head())
# print(gwanak_df.tail())
# Out:
#     지역코드  법정동       지번     연립다세대  건축년도  층   전용면적     년  월  일   보증금액  월세금액  \
# 0  11620  봉천동   1536-6  양지맨션(나)동  1993  2  82.82  2015  1  1  22000     0
# 1  11620  봉천동    715-3      천우맨션  1991  3  70.47  2015  1  1  10000     0
# 2  11620  봉천동  635-218      벨유어블  2014  4  26.48  2015  1  1   3500    50
# 3  11620  봉천동   649-41  넥스트월드하우스  2001  1  29.66  2015  1  2   8500     0
# 4  11620  봉천동   647-88  (647-88)  1986  1  54.52  2015  1  2   7500     0
#
#    계약구분  계약기간 갱신요구권사용  종전계약보증금  종전계약월세
# 0  None  None    None     <NA>    <NA>
# 1  None  None    None     <NA>    <NA>
# 2  None  None    None     <NA>    <NA>
# 3  None  None    None     <NA>    <NA>
# 4  None  None    None     <NA>    <NA>

# %%
# 광진구
gwangjin_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11215",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(gangseo_df.head())
print(gangseo_df.tail())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 광진구
# ----> 2 gwangjin_df = api.get_data(
#       3     property_type="연립다세대",
#       4     trade_type="전월세",
#       5     sigungu_code="11215",
#       6     start_year_month = "201501",
#       7     end_year_month = "202212"
#       8     )
#       9 print(gangseo_df.head())
#      10 print(gangseo_df.tail())
#
# NameError: name 'api' is not defined

# %%
# 구로구
guro_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11530",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(gangseo_df.head())
print(gangseo_df.tail())
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # 구로구
# ----> 2 guro_df = api.get_data(
#       3     property_type="연립다세대",
#       4     trade_type="전월세",
#       5     sigungu_code="11530",
#       6     start_year_month = "201501",
#       7     end_year_month = "202212"
#       8     )
#       9 print(gangseo_df.head())
#      10 print(gangseo_df.tail())
#
# File C:\Anaconda3\Lib\site-packages\PublicDataReader\PublicDataPortal\molit.py:177, in TransactionPrice.get_data(self, property_type, trade_type, sigungu_code, year_month, start_year_month, end_year_month, verbose, **kwargs)
#     175 if res_json['response']['header']['resultCode'] != '00':
#     176     error_message = res_json['response']['header']['resultMsg']
# --> 177     raise Exception(error_message)
#     178 items = res_json['response']['body']['items']
#     179 if not items:
#
# ...

# %%
# 금천구
geumcheon_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11545",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(geumcheon_df.head())
print(geumcheon_df.tail())

# %%
# 노원구
nowon_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11350",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(nowon_df.head())
print(nowon_df.tail())

# %%
# 도봉구
dobong_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11320",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(dobong_df.head())
print(dobong_df.tail())

# %%
# 동대문구
dongdaemun_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11230",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(dongdaemun_df.head())
print(dongdaemun_df.tail())

# %%
# 동작구
dongjak_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11590",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(dongjak_df.head())
print(dongjak_df.tail())

# %%
# 마포구
mapo_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11440",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(mapo_df.head())
print(mapo_df.tail())

# %%
# 서대문구
seodaemun_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11410",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(seodaemun_df.head())
print(seodaemun_df.tail())

# %%
# 서초구
seocho_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11650",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(seocho_df.head())
print(seocho_df.tail())

# %%
# 성동구
seongdong_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11200",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(seongdong_df.head())
print(seongdong_df.tail())

# %%
# 성북구
seongbuk_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11290",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(seongbuk_df.head())
print(seongbuk_df.tail())

# %%
# 송파구
songpa_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11710",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(songpa_df.head())
print(songpa_df.tail())

# %%
# 양천구
yangcheon_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11470",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(yangcheon_df.head())
print(yangcheon_df.tail())

# %%
# 영등포구
yeongdeungpo_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11560",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(yeongdeungpo_df.head())
print(yeongdeungpo_df.tail())

# %%
# 용산구
yongsan_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11170",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(yongsan_df.head())
print(yongsan_df.tail())

# %%
# 은평구
eunpyeong_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11380",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(eunpyeong_df.head())
print(eunpyeong_df.tail())

# %%
# 종로구
jongno_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11110",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(jongno_df.head())
print(jongno_df.tail())

# %%
# 중구
jung_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11140",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(jung_df.head())
print(jung_df.tail())

# %%
# 중랑구
jungnang_df = api.get_data(
    property_type="연립다세대",
    trade_type="전월세",
    sigungu_code="11260",
    start_year_month = "201501",
    end_year_month = "202212"
    )
print(jungnang_df.head())
print(jungnang_df.tail())
